# %%
path='웰니스_대화_스크립트_데이터셋.xlsx'

# %%
import pandas as pd

# %%
data=pd.read_excel(path)

# %%
data.to_csv('welness.csv',index = False)

# %%
wel=pd.read_csv('welness.csv')

# %%
wel[ ['유저', '챗봇', '구분',] ]
# Out:
#                                                    유저  \
# 0     제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1                            더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2                         하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 3                                   꼭 롤러코스터 타는 것 같아요.
# 4                          롤러코스터 타는 것처럼 기분이 왔다 갔다 해요.
# ...                                               ...
# 5226             한숨 자고 일어나면 괜찮으려나? 해서 자고 일어났는데도 똑같아요.
# 5227                            자고 나면 괜찮을 줄 알았는데 비슷해…
# 5228                                 지금도 상태가 계속 안 좋아.
# 5229                       이게 제 마음과 상관없이 증상이 계속 나타나요.
# 5230                    나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.
#
#                                            챗봇         구분
# 0             감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.  감정/감정조절이상
# 1                      저도 그 기분 이해해요. 많이 힘드시죠?  감정/감정조절이상
# 2     그럴 때는 밥은 잘 먹었는지, 잠은 잘 잤는지 체크해보는 것도 좋아요.  감정/감정조절이상
# 3                                         NaN  감정/감정조절이상
# ...

# %%
wel[wel['구분']=='감정/감정조절이상']
# Out:
#            구분                                               유저  \
# 0   감정/감정조절이상  제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1   감정/감정조절이상                         더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2   감정/감정조절이상                      하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 3   감정/감정조절이상                                꼭 롤러코스터 타는 것 같아요.
# 4   감정/감정조절이상                       롤러코스터 타는 것처럼 기분이 왔다 갔다 해요.
# 5   감정/감정조절이상                       작년 가을부터 감정조절이 잘 안 되는 거 같아.
# 6   감정/감정조절이상                        예전에 비해서 인내심이 너무 짧아진 거 같아.
# 7   감정/감정조절이상                            더 이상 혼자서는 감정조절을 못하겠어.
# 8   감정/감정조절이상                         점점 나 자신을 컨트롤하지 못하는 기분이야.
# 9   감정/감정조절이상                            나도 이러기 싫은데 내 마음대로 안돼.
# 10  감정/감정조절이상                        맨정신일 때는 저를 주체할 수 가 없었거든요.
# 11  감정/감정조절이상                                         주체가 안 돼.
# 12  감정/감정조절이상           이렇게 쌓이고 쌓이다 나중에 확 터지거든요. 진짜 걷잡을 수 없이요.
# 13  감정/감정조절이상                           근데 감정을 다스리지 못해 욱하기도하고.
# ...

# %%
for i,j in wel.iterrows():
    if str(wel.iloc[i]['챗봇'])=='nan':
            wel.iloc[i]['챗봇']=wel.iloc[i-1]['챗봇']

# %%
wel=wel.rename(columns={"유저": "Q", "챗봇": "A","구분":'label'})

# %%
wel=wel[['Q','A','label']]

# %%
c_df=pd.read_csv('ChatbotData.csv')

# %%
c_df['label']=c_df['label'].astype(str)
c_df.info()
wel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11823 entries, 0 to 11822
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       11823 non-null  object
#  1   A       11823 non-null  object
#  2   label   11823 non-null  object
# dtypes: object(3)
# memory usage: 277.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5231 entries, 0 to 5230
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       5231 non-null   object
#  1   A       5231 non-null   object
#  2   label   5231 non-null   object
# dtypes: object(3)
# memory usage: 122.7+ KB

# %%
data=pd.concat([c_df,wel])

# %%
data.to_csv('data.csv',index = False)

# %%
data=pd.read_csv('data.csv')

# %%
data
# Out:
#                                           Q                           A  \
# 0                                    12시 땡!                  하루가 또 가네요.
# 1                               1지망 학교 떨어졌어                   위로해 드립니다.
# 2                              3박4일 놀러가고 싶다                 여행은 언제나 좋죠.
# 3                           3박4일 정도 놀러가고 싶다                 여행은 언제나 좋죠.
# 4                                   PPL 심하네                  눈살이 찌푸려지죠.
# ...                                     ...                         ...
# 17049  한숨 자고 일어나면 괜찮으려나? 해서 자고 일어났는데도 똑같아요.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 17050                 자고 나면 괜찮을 줄 알았는데 비슷해…  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 17051                      지금도 상태가 계속 안 좋아.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 17052            이게 제 마음과 상관없이 증상이 계속 나타나요.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 17053         나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
#
#            label
# 0              0
# 1              0
# 2              0
# 3              0
# ...

# %%
# Out:
#                                          Q                           A  \
# 0                                   12시 땡!                  하루가 또 가네요.
# 1                              1지망 학교 떨어졌어                   위로해 드립니다.
# 2                             3박4일 놀러가고 싶다                 여행은 언제나 좋죠.
# 3                          3박4일 정도 놀러가고 싶다                 여행은 언제나 좋죠.
# 4                                  PPL 심하네                  눈살이 찌푸려지죠.
# ...                                    ...                         ...
# 5226  한숨 자고 일어나면 괜찮으려나? 해서 자고 일어났는데도 똑같아요.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 5227                 자고 나면 괜찮을 줄 알았는데 비슷해…  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 5228                      지금도 상태가 계속 안 좋아.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 5229            이게 제 마음과 상관없이 증상이 계속 나타나요.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 5230         나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.  너무 심하시면 병원을 다시 가보는 건 어떨까요?
#
#           label
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...
